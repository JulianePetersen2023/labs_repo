# %%
import pandas as pd

# %%
s1 = pd.read_csv(r"C:\Users\Juliane\Documents\GitHub\labs_repo\s1_df.csv")
s2 = pd.read_csv(r"C:\Users\Juliane\Documents\GitHub\labs_repo\s2_df.csv")
s3 = pd.read_csv(r"C:\Users\Juliane\Documents\GitHub\labs_repo\s3_df.csv")
s4 = pd.read_csv(r"C:\Users\Juliane\Documents\GitHub\labs_repo\s4_df.csv")
s5 = pd.read_csv(r"C:\Users\Juliane\Documents\GitHub\labs_repo\s5_df.csv")
s6 = pd.read_csv(r"C:\Users\Juliane\Documents\GitHub\labs_repo\s6_df.csv")
s7 = pd.read_csv(r"C:\Users\Juliane\Documents\GitHub\labs_repo\s7_df.csv")
s8 = pd.read_csv(r"C:\Users\Juliane\Documents\GitHub\labs_repo\s8_df.csv")

# %%
result_df = pd.concat([s1, s2, s3, s4, s5, s6, s7], ignore_index=True)

df = pd.DataFrame(result_df)

df
# Out:
#      danceability   energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.765  0.52900    4    -8.243     0       0.2340         0.408
# 1           0.605  0.46000    8    -7.360     1       0.0476         0.467
# 2           0.679  0.48400    9   -10.156     0       0.0279         0.683
# 3           0.717  0.68000    0    -6.263     1       0.0371         0.466
# 4           0.496  0.80200    8    -3.684     1       0.0396         0.107
# ..            ...      ...  ...       ...   ...          ...           ...
# 858         0.108  0.01360    0   -27.620     0       0.0426         0.895
# 859         0.174  0.00950    8   -36.054     1       0.0440         0.843
# 860         0.131  0.01450    0   -30.363     1       0.0366         0.826
# 861         0.194  0.00739    1   -38.915     1       0.0507         0.960
# 862         0.127  0.05680    1   -19.729     1       0.0382         0.930
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
df.to_csv(r'C:\Users\Juliane\Documents\GitHub\labs_repo\music_df.csv', index=False)

# %%
#DROP UNNECESSARY COLUMNS
# df_ids = df.drop(('key', 'mode', 'type', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'), axis=1)
columns_to_drop = ['key', 'mode', 'type', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature', 'id']
df_new = df.drop(columns=columns_to_drop, axis=1)
