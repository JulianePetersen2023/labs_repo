# %%
import pandas as pd

# %%
Environ=pd.read_csv(r"C:\Users\Juliane\Desktop\Data analytics\my_project\Enivromental Innovations.csv")
CP=pd.read_csv(r"C:\Users\Juliane\Desktop\Data analytics\My_project\Child_Abuse_Prevention_Services_in_San_Francisco.csv")
EU=pd.read_csv(r"C:\Users\Juliane\Desktop\CRR_data\cordisref-H2020topics.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[9], line 3
#       1 Environ=pd.read_csv(r"C:\Users\Juliane\Desktop\Data analytics\my_project\Enivromental Innovations.csv")
#       2 CP=pd.read_csv(r"C:\Users\Juliane\Desktop\Data analytics\My_project\Child_Abuse_Prevention_Services_in_San_Francisco.csv")
# ----> 3 EU=pd.read_csv(r"C:\Users\Juliane\Desktop\CRR_data\cordisref-H2020topics.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
# ...

# %%
EU=pd.read_csv(r"C:\Users\Juliane\Desktop\CRR_data\cordisref-H2020topics.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 EU=pd.read_csv(r"C:\Users\Juliane\Desktop\CRR_data\cordisref-H2020topics.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df
# Out:
#                                        innovation name Paper value chain  \
# 0                     Crowdfunding for climate finance                No
# 1                                   Green Climate Fund                No
# 2        Corporate Emissions Disclosure and Divestment                No
# 3                                           LingoBoost               Yes
# 4                                            FibreForm               Yes
# ..                                                 ...               ...
# 104                             World Bank Green Bonds               Yes
# 105                      Friesland Campina Green Bonds                No
# 106  IIGCC(Insitutional investors group on climate ...               Yes
# 107  Ceres Investor Network on Climate risk and Sus...               Yes
# 108                                 EIB 25% Commitment               Yes
#
#     Plastic value chain                                  Steel value chain  \
# ...

# %%
Data
# Out:
#                                                    title  up_vote  \
# 0         Kaggle Has Officially Passed 14 MILLION Users!     24.0
# 1                          I became a Notebooks Expert!!     30.0
# 2                                  🎉 3x Kaggle Expert! 🎉     25.0
# 3                         [LB 409] my experiment results     20.0
# 4                    ⭐ TOP 10 Kagglers on Discussions 🤜🤛     24.0
# ...                                                  ...      ...
# 18514    What are the best results using only news data?      2.0
# 18515                 1 hour to go OR 13 hours to go ???      3.0
# 18516                      fastai import error on Kaggle      0.0
# 18517  Machine Learning (4 x Nvidia GTX1070 GPU) serv...      0.0
# 18518  What is the normal range of f1 score in valid ...      0.0
#
#                   author                                       comment_type  \
# 0             Justin Oh                                         in General
# ...

# %%
CP
# Out:
#                           Program or Contract Name  \
# 0                            Mission Family Center
# 1    Child Health and Disability Prevention (CHDP)
# 2                    Child Protection Center (CPC)
# 3          Counseling Enriched Educational Program
# 4                    ACES screening for caregivers
# ..                                             ...
# 370                         Youth Justice Services
# 371                           Youth Moving Forward
# 372                      Youth Services Prevention
# 373                    Youth Transitional Services
# 374                  ZSFG Health Advocates Program
#
#                                Contractor Name  \
# 0                                          NaN
# 1                                          NaN
# 2    Edgewood Center for Children and Families
# 3                   Edgewood Children's Center
# 4                                          NaN
# ..                                         ...
# ...

# %%
SI = pd.read_csv(r"C:\Users\Juliane\Desktop\CRR_data\sie_projects.csv")

# %%
SI
# Out:
#                                           Project Name  \
# 0                             Gerontechnology Platform
# 1    Start from the Beginning - Chinese Supporting ...
# 2                                          FOOD-CO 2.0
# 3              Second Evaluation Study of the SIE Fund
# 4                                              FOOD-CO
# ..                                                 ...
# 499                                     Love Your Ears
# 500                                         Mindbridge
# 501                                     NEVER TOO LATE
# 502                                        Petvolution
# 503                                              星夢GPS
#
#                                               項目名稱  \
# 0                                           樂齡科技平台
# 1    從起步開始 --- 幼稚園非華語學生學習中文支援計劃按效益付費計劃 (2020-2023)
# 2                                      FOOD-CO 2.0
# 3                                      第二期社創基金評估研究
# ...
