# %%
# 1. import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# 2. find url and store it in a variable
url = "https://ec.europa.eu/european-social-fund-plus/en/projects"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")
# 4.2. check that the html code looks like it should
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://ec.europa.eu/european-social-fund-plus/en/projects" rel="canonical"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <script type="application/json">{"utility":"piwik","siteID":"646","sitePath":["ec.europa.eu\/european-social-fund-plus"],"instance":"ec.europa.eu"}</script>
# <script type="application/json">{"utility":"cck"}</script>
# <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/european-social-fund-plus/themes/contrib/oe_theme/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
# <title>Projects | European Social Fund Plus</title>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://ec.europa.eu/european-social-fund-plus/en/projects" rel="canonical"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <script type="application/json">
#    {"utility":"piwik","siteID":"646","sitePath":["ec.europa.eu\/european-social-fund-plus"],"instance":"ec.europa.eu"}
#   </script>
#   <script type="application/json">
#    {"utility":"cck"}
#   </script>
#   <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="/european-social-fund-plus/themes/contrib/oe_theme/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/>
#   <title>
#    Projects | European Social Fund Plus
#   </title>
# ...

# %%
# looking for product name, i.e.: h5 class="card-title"> TricyLift </h5>
# CSS selector copied: "#algolia-hits > div > ol > li:nth-child(2) > a > div > div.card-body > h5"

# TRIED ALL DIFFERENT VERSIONS AND THEN REALISED THAT THOSE ATTRIBUTES ARE NOT EVEN IN THE SOUP (i.e. searching for H5)

# %%
soup.select("a div div.card-body h5")
# Out:
# []

# %%
soup.select("h1 a")
# Out:
# [<a class="ecl-link ecl-link--standalone" href="/european-social-fund-plus/en/projects/brothers-help-prevent-violence-among-young-men">‘Brothers’ help prevent violence among young men</a>,
#  <a class="ecl-link ecl-link--standalone" href="/european-social-fund-plus/en/projects/online-services-help-young-people-rural-areas-get-access-skills-and-employment">Online services help young people in rural areas get access to skills and employment</a>,
#  <a class="ecl-link ecl-link--standalone" href="/european-social-fund-plus/en/projects/day-care-centres-help-older-persons-meet-day-day-needs">Day-care centres help older persons meet day-to-day needs</a>,
#  <a class="ecl-link ecl-link--standalone" href="/european-social-fund-plus/en/projects/czech-profem-project">Czech victims of violence find a path to a new life </a>,
# ...

# %%
soup.select("a")  #div div.card-body h5
# Out:
# [<a class="btn btn-motion inverted" data-izimodal-close="" id="accept-solution-explorer-info">Explore</a>,
#  <a href="https://solarimpulse.com/files/medias/files/1635489775-Solutions-Explorer-Factsheet.pdf" style="margin-top:10px; margin-right:20px; float: right;" target="_blank">Learn more</a>,
#  <a class="btn btn-motion outline" data-izimodal-close="">Cancel</a>,
#  <a class="btn btn-motion inverted btn-ajax" data-izimodal-close="">Confirm</a>,
#  <a href="https://solarimpulse.com/solutions-explorer/city">Solutions City</a>,
#  <a href="#" id="assistant-btn-trigger">Assistant</a>,
#  <a href="#" id="search-btn-trigger">Search</a>,
#  <a href="https://solarimpulse.com/solutions-explorer">Solutions Explorer</a>,
#  <a data-izimodal-open="#iziModal-about">
#  <i class="fas fa-info-circle"></i>
#  </a>,
#  <a class="panel-close" href="#"><i class="fas fa-times"></i></a>,
#  <a class="btn btn-radius btn-primary m-b-i" href="/my-login">Sign in</a>,
# ...

# %%
#products = []
#for p in soup.select("..."):
#   products.append(p.get_text())
