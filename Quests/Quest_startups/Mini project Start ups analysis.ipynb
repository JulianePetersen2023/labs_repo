# %%
import pandas as pd 

df = pd.read_csv("https://raw.githubusercontent.com/Esther-Velasco/esther_labs/main/W3/Mini%20project/Startups%20in%202021%20end.csv", on_bad_lines='skip')
df
# Out:
#      Unnamed: 0          Company Valuation ($B) Date Joined        Country  \
# 0             0        Bytedance           $140    4/7/2017          China
# 1             1           SpaceX         $100.3   12/1/2012  United States
# 2             2           Stripe            $95   1/23/2014  United States
# 3             3           Klarna          $45.6  12/12/2011         Sweden
# 4             4            Canva            $40    1/8/2018      Australia
# ..          ...              ...            ...         ...            ...
# 931         931        YipitData             $1   12/6/2021  United States
# 932         932         Anyscale             $1   12/7/2021  United States
# 933         933  Iodine Software             $1   12/1/2021  United States
# 934         934       ReliaQuest             $1   12/1/2021  United States
# 935         935       Pet Circle             $1   12/7/2021      Australia
#
#               City                         Industry  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'Valuation ($B)', 'Date Joined', 'Country',
#        'City', 'Industry', 'Select Investors'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Unnamed: 0          936
# Company             935
# Valuation ($B)      192
# Date Joined         589
# Country              47
# City                239
# Industry             17
# Select Investors    920
# dtype: int64

# %%
df.Industry.value_counts()
# Out:
# Fintech                                190
# Internet software & services           167
# E-commerce & direct-to-consumer        102
# Artificial intelligence                 69
# Health                                  63
# Supply chain, logistics, & delivery     51
# Other                                   51
# Cybersecurity                           41
# Mobile & telecommunications             37
# Data management & analytics             36
# Hardware                                32
# Auto & transportation                   29
# Edtech                                  27
# Consumer & retail                       23
# Travel                                  13
# Artificial Intelligence                  4
# Finttech                                 1
# Name: Industry, dtype: int64

# %%
industry_mapping = {
    "Artificial intelligence":"Artificial intelligence",
    "Artificial Intelligence":"Artificial intelligence"                    
}

df['Industry']= list(map(lambda x:industry_mapping.get(x,x),df['Industry']))

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns = df.columns.str.lower()

# %%
startups = df.drop(("select_investors"), axis = 1)
startups = df.drop(("unnamed:_0"), axis = 1)
startups
# Out:
#              company valuation_($b) date_joined        country           city  \
# 0          Bytedance           $140    4/7/2017          China        Beijing
# 1             SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2             Stripe            $95   1/23/2014  United States  San Francisco
# 3             Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4              Canva            $40    1/8/2018      Australia    Surry Hills
# ..               ...            ...         ...            ...            ...
# 931        YipitData             $1   12/6/2021  United States       New York
# 932         Anyscale             $1   12/7/2021  United States       Berkeley
# 933  Iodine Software             $1   12/1/2021  United States         Austin
# 934       ReliaQuest             $1   12/1/2021  United States          Tampa
# 935       Pet Circle             $1   12/7/2021      Australia     Alexandria
#
# ...

# %%
startups.country.value_counts()
# Out:
# United States           477
# China                   169
# India                    51
# United Kingdom           37
# Germany                  23
# Israel                   21
# France                   19
# Brazil                   15
# Canada                   15
# South Korea              11
# Singapore                11
# Hong Kong                 7
# Japan                     6
# Australia                 6
# Netherlands               5
# Mexico                    5
# Switzerland               4
# Sweden                    4
# Indonesia                 4
# Spain                     4
# Norway                    3
# Ireland                   3
# United Arab Emirates      3
# Turkey                    2
# Colombia                  2
# Belgium                   2
# Austria                   2
# Finland                   2
# Denmark                   2
# Philippines               2
# Thailand                  2
# South Africa              2
# Luxembourg                1
# ...

# %%
country_mapping = {
    "United States":"United States",
    "United States,":"United States",
    "Indonesia":"Indonesia",
    "Indonesia,":"Indonesia"
}

startups['country']= list(map(lambda x:country_mapping.get(x,x),startups['country']))

# %%
startups.country.unique()
# Out:
# array(['China', 'United States', 'Sweden', 'Australia', 'United Kingdom',
#        'Brazil', 'Hong Kong', 'India', 'Indonesia', 'Germany', 'Mexico',
#        'Canada', 'Turkey', 'South Korea', 'Netherlands', 'Israel',
#        'Colombia', 'Belgium', 'Lithuania', 'Estonia', 'France', 'Austria',
#        'Ireland', 'Singapore', 'Vietnam', 'United Arab Emirates',
#        'Switzerland', 'Argentina', 'Spain', 'Japan', 'Luxembourg',
#        'Nigeria', 'Santa Clara', 'Finland', 'Philippines', 'Denmark',
#        'Senegal', 'Bermuda', 'Norway', 'South Africa', 'Chile',
#        'Thailand', 'Malaysia', 'Czech Republic', 'Croatia'], dtype=object)

# %%
city_mapping = {
    "South San Francisco":"San Francisco",
    "Tel Aviv-Yafo,":"Tel Aviv",
    "Washington":"Washington DC",
}

startups['city']= list(map(lambda x:city_mapping.get(x,x),startups['city']))

# %%
startups
# Out:
#              company valuation_($b) date_joined        country           city  \
# 0          Bytedance           $140    4/7/2017          China        Beijing
# 1             SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2             Stripe            $95   1/23/2014  United States  San Francisco
# 3             Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4              Canva            $40    1/8/2018      Australia    Surry Hills
# ..               ...            ...         ...            ...            ...
# 931        YipitData             $1   12/6/2021  United States       New York
# 932         Anyscale             $1   12/7/2021  United States       Berkeley
# 933  Iodine Software             $1   12/1/2021  United States         Austin
# 934       ReliaQuest             $1   12/1/2021  United States          Tampa
# 935       Pet Circle             $1   12/7/2021      Australia     Alexandria
#
# ...

# %%
df_clean = startups.drop(("select_investors"), axis = 1)

#we figured we needed to create the foreign key values data so we create index columns for city_id, 
#country_id, startup_id and industry_id

# %%
df_clean["country_id"]= range(1, len(df_clean) + 1)
df_clean["city_id"] = range(1, len(df_clean) + 1)
df_clean["startup_id"] = range(1, len(df_clean) + 1)
df_clean["industry_id"] = range(1, len(df_clean) + 1)
df_clean
# Out:
#              company valuation_($b) date_joined        country           city  \
# 0          Bytedance           $140    4/7/2017          China        Beijing
# 1             SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2             Stripe            $95   1/23/2014  United States  San Francisco
# 3             Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4              Canva            $40    1/8/2018      Australia    Surry Hills
# ..               ...            ...         ...            ...            ...
# 931        YipitData             $1   12/6/2021  United States       New York
# 932         Anyscale             $1   12/7/2021  United States       Berkeley
# 933  Iodine Software             $1   12/1/2021  United States         Austin
# 934       ReliaQuest             $1   12/1/2021  United States          Tampa
# 935       Pet Circle             $1   12/7/2021      Australia     Alexandria
#
# ...

# %%
# Specify the path where you want to save the CSV file
output_path = "https://github.com/Esther-Velasco/esther_labs/tree/main/W3/Mini%20project"

# Use the to_csv method to save the DataFrame to a CSV file
df_clean.to_csv("startups_index.csv", index=False)
